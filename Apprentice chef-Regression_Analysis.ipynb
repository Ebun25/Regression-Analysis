# %% [markdown]
# SUMMARY
# Apprentice Chef, Inc. is a company that provides daily prepared gourmet meals to busy professionals. Customers can order the meals through a user-friendly online platform or mobile app and each meal takes 30 minutes or less to finish cooking. The company also offers master cooking classes and a weekly meal plan with discounts. The meal sets come with disposable cookware and range in price from $10 to $23. The ordering platform allows for filtering based on cuisine and recommendations are made based on previous purchases, similarity to other customers, and trending products. The company's mission is to support the busy lifestyle of working professionals with delicious and healthy eating. The key value propositions of the company, according to market research, are convenience, variety, and healthy options.
# However, to determine how various factors influence the revenue of the company. A regression model was developed using a dataset.
#
# DATA ANALYSIS
# To gain insight into the factors affecting revenue of the company, a thorough analysis was conducted to determine the correlation between various variables and revenue. The results of this analysis revealed that some variables were positively correlated with revenue, while others were negatively correlated or not correlated at all.
# To gain further insights into the data, a histogram was created to examine the skewness of the data. The histogram revealed that the data was skewed. To correct this issue, the regression model was used to transform certain variables into logarithmic form, which was then saved in the dataset. A new histogram was then created, which showed that the data was now well-skewed.
# The ordinary Least Square (OLS) model was used, utilizing the statsmodel library, to analyze the relationship between the logarithmic transformations of revenue and the various continuous variables in the dataset. The logarithmic variables studied include average time on site, total meals ordered, total photo viewed, contact with customer service, average mean rating, and unique meals purchased.
# The result of the analysis indicate that the model has a moderate level of explanatory power, as indicated by the R-squared and adjusted R-squared values of 0.449 and 0.448, respectively. Additionally, the p-value of 0.000 suggests that the factors included in the model are statistically significant in explaining the logarithmic form of the company’s revenue. These results suggest that the independent variables have a significant impact on revenue.
#
# The "train_test_split" function from scikit-learn is used to split the data into two parts, a training set and a testing set. The "train_test_split" function splits the data into training and testing sets, with the test set size being specified by the argument "test_size" and set to 0.25. The argument "random_state" is set to 219, which ensures that the data is split in a consistent manner each time the code is run. The purpose of splitting the data into a training set and a testing set is to evaluate the performance of the model
#
# Fitting the model to the training data (x_train and y_train) using the fit method of the Linear Regression object. The model is then used to make predictions on the test data (x_test) using the predict method.
#
# The performance of the model is evaluated by calculating the R-squared values for both the training and test datasets. The R-squared value is a measure of how well the model fits the data. It ranges from 0 to 1, with higher values indicating a better fit. In this case, the training score is 0.6681 and the testing score is 0.673.
#
# The train-test gap is calculated as the difference between the training and testing scores. In this case, the gap is 0.0049, which is relatively small. This suggests that the model has good generalization performance, meaning it can make accurate predictions on unseen data.
#
# The code then lists the coefficients for each independent variable in the model, along with their corresponding feature names. These coefficients represent the strength and direction of the relationship between the independent variable and the dependent variable. Positive coefficients indicate a positive relationship (as the independent variable increases, so does the dependent variable), while negative coefficients indicate a negative relationship (as the independent variable increases, the dependent variable decreases). The intercept is the constant value in the model, which represents the expected value of the dependent variable when all independent variables are equal to zero.
# From the analysis  of the linear regression analysis, where each feature (i.e. independent variable) in the model is paired with its corresponding coefficient. The coefficients represent the relationship between the feature and the dependent variable.The intercept (i.e. the constant term) is 4.07. This means that when all the features are zero, the estimated value of the dependent variable is 4.07.The coefficient for "log arithmetic average time per site visit" is 0.48, which means that for a one unit increase in the " log arithmetic average time per site visit " feature, the estimated value of the dependent variable increases by 0.48. Similarly, the coefficients for the other features represent the relationship between each feature and the dependent variable.
#
# The ARD regression which was also trained on some data was used in measuring the accuracy of the model's predictions by comparing them to the actual values. The accuracy of the model is being measured using the R-square metric.
# The training score of the model is 0.6681, which means that the model's predictions are off by an average of 0.6681 when compared to the actual values in the training data. The testing score of the model is 0.6726, which means that the model's predictions are off by an average of 0.6726 when compared to the actual values in the testing data. The train-test gap is 0.0045, which means that there is a small difference between the training score and the testing score.
# A Decision Tree Regressor was trained using a randomized search cross-validation approach. The random search cross-validation approach randomly samples a set of hyperparameters from the provided parameter grid and trains the model with those hyperparameters. The performance of the model is then evaluated using cross-validation with 5 folds. This process is repeated 1000 times and the hyperparameters that result in the best performance (highest AUC score) are saved as the "best parameters."
#
# The final output indicates that the best training AUC achieved was 0.6558, which is the average cross-validated AUC score across all 5 folds for the best hyperparameters. The AUC of 0.6558 means the model's performance is better than random.
#
# This code trains a Decision Tree Regressor using the hyperparameters that were found to be optimal in the previous randomized search cross-validation step. The model is fit to the training data using the fit method. The predict method is then used to make predictions on the test data.
#
# The code then calculates and outputs the model's score on both the training data and the test data using the score method. The score method returns the coefficient of determination (R^2) which is a measure of how well the model fits the data. A value of 1.0 indicates a perfect fit, and a value of 0.0 indicates a constant model that only predicts the mean of the target values. So, a score of 0.7584 on the training data and 0.7123 on the test data indicates that the model has a good fit to the training data.
# Finally, the code calculates the difference between the training score and the test score, which is 0.0460 in this case. This difference, also known as generalization error, measures how well the model generalizes to new unseen data.

# %%
# importing libraries
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 


# setting print options for pandas
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)


# specifying file name and reading the file into python
file = './__datasets/Apprentice_Chef_Dataset_2023.xlsx'
chef = pd.read_excel(io = file)


# displaying first ten rows of the dataset
chef.head(n = 5)
# Out:
#    REVENUE                    NAME                             EMAIL FIRST_NAME FAMILY_NAME  TOTAL_MEALS_ORDERED  UNIQUE_MEALS_PURCH  CONTACTS_W_CUSTOMER_SERVICE  PRODUCT_CATEGORIES_VIEWED  AVG_TIME_PER_SITE_VISIT  CANCELLATIONS_AFTER_NOON  PC_LOGINS  MOBILE_LOGINS  WEEKLY_PLAN  LATE_DELIVERIES   AVG_PREP_VID_TIME  LARGEST_ORDER_SIZE  AVG_MEAN_RATING  TOTAL_PHOTOS_VIEWED
# 0   4920.0       Steffon Baratheon       steffon.baratheon@yahoo.com    Steffon   Baratheon                  493                   9                            1                         10                    265.6                         5          5              2            0                 0             137.41                   6         2.894737                  456
# ...

# %%
for column in chef:
    print(column)
# Out:
# REVENUE
# NAME
# EMAIL
# FIRST_NAME
# FAMILY_NAME
# TOTAL_MEALS_ORDERED
# UNIQUE_MEALS_PURCH
# CONTACTS_W_CUSTOMER_SERVICE
# PRODUCT_CATEGORIES_VIEWED
# AVG_TIME_PER_SITE_VISIT
# CANCELLATIONS_AFTER_NOON
# PC_LOGINS
# MOBILE_LOGINS
# WEEKLY_PLAN
# LATE_DELIVERIES
# AVG_PREP_VID_TIME
# LARGEST_ORDER_SIZE
# AVG_MEAN_RATING
# TOTAL_PHOTOS_VIEWED

# %%
##Based on the for loop output above , classified the columns to it's original variable in the dataset.
### To be taken off
CONTINUOUS
Revenue (Y variable)
AVG_TIME_PER_SITE_VISIT
AVG_PREP_VID_TIME
AVG_MEAN_RATING
LARGEST_ORDER_SIZE

INTERVAL/COUNT
TOTAL_MEALS_ORDERED
UNIQUE_MEALS_PURCH
PRODUCT_CATEGORIES_VIEWED
PRODUCT_CATEGORIES_VIEWED
PC_LOGINS
MOBILE_LOGINS
WEEKLY_PLAN
LATE_DELIVERIES 

TOTAL_PHOTOS_VIEWED

CATEGORICAL
NAME
EMAIL
FIRST_NAME
FAMILY_NAME

# %%
chef.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1946 entries, 0 to 1945
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   REVENUE                      1946 non-null   float64
#  1   NAME                         1946 non-null   object
#  2   EMAIL                        1946 non-null   object
#  3   FIRST_NAME                   1946 non-null   object
#  4   FAMILY_NAME                  1900 non-null   object
#  5   TOTAL_MEALS_ORDERED          1946 non-null   int64
#  6   UNIQUE_MEALS_PURCH           1946 non-null   int64
#  7   CONTACTS_W_CUSTOMER_SERVICE  1946 non-null   int64
#  8   PRODUCT_CATEGORIES_VIEWED    1946 non-null   int64
#  9   AVG_TIME_PER_SITE_VISIT      1946 non-null   float64
#  10  CANCELLATIONS_AFTER_NOON     1946 non-null   int64
#  11  PC_LOGINS                    1946 non-null   int64
#  12  MOBILE_LOGINS                1946 non-null   int64
# ...

# %%
# Giving names to missing data in family name
Lost_name = 0

chef['FAMILY_NAME'] = chef['FAMILY_NAME'].fillna(Lost_name)

# %%
# describing the data
chef.describe(include = 'number').round(decimals = 2)
# Out:
#        REVENUE  TOTAL_MEALS_ORDERED  UNIQUE_MEALS_PURCH  CONTACTS_W_CUSTOMER_SERVICE  PRODUCT_CATEGORIES_VIEWED  AVG_TIME_PER_SITE_VISIT  CANCELLATIONS_AFTER_NOON  PC_LOGINS  MOBILE_LOGINS  WEEKLY_PLAN  LATE_DELIVERIES   AVG_PREP_VID_TIME  LARGEST_ORDER_SIZE  AVG_MEAN_RATING  TOTAL_PHOTOS_VIEWED
# count  1946.00              1946.00             1946.00                       1946.0                    1946.00                  1946.00                   1946.00    1946.00        1946.00      1946.00           1946.00            1946.00             1946.00          1946.00              1946.00
# mean   2107.29                74.63                6.98                          4.9                       5.38                   150.56                      1.57       5.52           1.48        11.33              2.05              99.60                4.44             3.55               113.15
# ...

# %%
# establishing a list of continuous features, such as REVENUE, and creating a correlation matrix based on those features
continuous_data = ['REVENUE','NAME','EMAIL','FIRST_NAME','FAMILY_NAME','TOTAL_MEALS_ORDERED','UNIQUE_MEALS_PURCH','CONTACTS_W_CUSTOMER_SERVICE',
'PRODUCT_CATEGORIES_VIEWED','AVG_TIME_PER_SITE_VISIT','CANCELLATIONS_AFTER_NOON','PC_LOGINS','MOBILE_LOGINS','WEEKLY_PLAN','LATE_DELIVERIES ',               
'AVG_PREP_VID_TIME','LARGEST_ORDER_SIZE','AVG_MEAN_RATING','TOTAL_PHOTOS_VIEWED']

chef_corr = chef[continuous_data].corr(method = 'pearson')

chef_corr.loc[ : , 'REVENUE'].round(decimals = 2).sort_values(ascending = False)
# Out:
# REVENUE                        1.00
# AVG_TIME_PER_SITE_VISIT        0.64
# TOTAL_MEALS_ORDERED            0.60
# TOTAL_PHOTOS_VIEWED            0.46
# LARGEST_ORDER_SIZE             0.44
# CONTACTS_W_CUSTOMER_SERVICE    0.17
# AVG_PREP_VID_TIME              0.14
# UNIQUE_MEALS_PURCH             0.10
# MOBILE_LOGINS                  0.07
# PRODUCT_CATEGORIES_VIEWED      0.03
# PC_LOGINS                      0.02
# WEEKLY_PLAN                    0.01
# CANCELLATIONS_AFTER_NOON       0.00
# LATE_DELIVERIES               -0.02
# AVG_MEAN_RATING               -0.55
# Name: REVENUE, dtype: float64

# %%
# developing a histogram using HISTPLOT with the following variables
sns.histplot(data  = chef,
         x     = 'REVENUE',
        kde    = True)


# title and axis labels
plt.title(label   = "Chef's Revenue")
plt.xlabel(xlabel = "REVENUE") 
plt.ylabel(ylabel = "Count")


# displaying the histogram
plt.show()


sns.histplot(data  = chef,
         x     = 'AVG_TIME_PER_SITE_VISIT',
        kde    = True)


# title and axis labels
plt.title(label   = "Visit Time")
plt.xlabel(xlabel = "AVG_TIME_PER_SITE_VISIT") 
plt.ylabel(ylabel = "Count")


# displaying the histogram
plt.show()


sns.histplot(data  = chef,
         x     = 'TOTAL_MEALS_ORDERED',
        kde    = True)


# title and axis labels
plt.title(label   = "MEALS_ORDERED")
plt.xlabel(xlabel = "TOTAL_MEALS_ORDERED") 
plt.ylabel(ylabel = "Count")


# displaying the histogram
plt.show()


sns.histplot(data  = chef,
         x     = 'TOTAL_PHOTOS_VIEWED',
        kde    = True)


# title and axis labels
plt.title(label   = "PHOTOS_VIEWED")
plt.xlabel(xlabel = "TOTAL_PHOTOS_VIEWED") 
plt.ylabel(ylabel = "Count")


# displaying the histogram
plt.show()

sns.histplot(data  = chef,
         x     = 'LARGEST_ORDER_SIZE',
        kde    = True)


# title and axis labels
plt.title(label   = "ORDER_SIZE")
plt.xlabel(xlabel = "LARGEST_ORDER_SIZE") 
plt.ylabel(ylabel = "Count")


# displaying the histogram
plt.show()

# %%
#transforming variables into log and saving it into the dataset
chef['log_REVENUE'] = np.log(chef['REVENUE'])
chef['log_AVG_TIME_PER_SITE_VISIT'] = np.log(chef['AVG_TIME_PER_SITE_VISIT'])
chef['log_TOTAL_MEALS_ORDERED'] = np.log(chef['TOTAL_MEALS_ORDERED']) 
chef['log_TOTAL_PHOTOS_VIEWED'] = np.log(chef['TOTAL_PHOTOS_VIEWED'])
chef['log_CONTACTS_W_CUSTOMER_SERVICE'] = np.log(chef['CONTACTS_W_CUSTOMER_SERVICE'])
chef['log_UNIQUE_MEALS_PURCH'] = np.log(chef['UNIQUE_MEALS_PURCH'])
chef['log_AVG_MEAN_RATING'] = np.log(chef['AVG_MEAN_RATING'])

# %%
for col in chef:
    print(col)
# Out:
# REVENUE
# NAME
# EMAIL
# FIRST_NAME
# FAMILY_NAME
# TOTAL_MEALS_ORDERED
# UNIQUE_MEALS_PURCH
# CONTACTS_W_CUSTOMER_SERVICE
# PRODUCT_CATEGORIES_VIEWED
# AVG_TIME_PER_SITE_VISIT
# CANCELLATIONS_AFTER_NOON
# PC_LOGINS
# MOBILE_LOGINS
# WEEKLY_PLAN
# LATE_DELIVERIES
# AVG_PREP_VID_TIME
# LARGEST_ORDER_SIZE
# AVG_MEAN_RATING
# TOTAL_PHOTOS_VIEWED
# log_REVENUE
# log_AVG_TIME_PER_SITE_VISIT
# log_TOTAL_MEALS_ORDERED
# log_TOTAL_PHOTOS_VIEWED
# log_CONTACTS_W_CUSTOMER_SERVICE
# log_UNIQUE_MEALS_PURCH
# log_AVG_MEAN_RATING

# %%
# developing a histogram using HISTPLOT and the logarithmetic function
sns.histplot(data   = chef,
          x      = 'log_REVENUE',
          kde    = True)


# title and axis labels
plt.title(label   = "Logarithmic Distribution of REVENUE")
plt.xlabel(xlabel = "log_REVENUE") 
plt.ylabel(ylabel = "Count")

# displaying the histogram
plt.show()

###
sns.histplot(data   = chef,
          x      = 'log_AVG_TIME_PER_SITE_VISIT',
          kde    = True)


# title and axis labels
plt.title(label   = "Logarithmic Distribution of AVG_TIME_PER_SITE_VISIT")
plt.xlabel(xlabel = "AVG_TIME_PER_SITE_VISIT") 
plt.ylabel(ylabel = "Count")

# displaying the histogram
plt.show()

###
sns.histplot(data   = chef,
          x      = 'log_TOTAL_MEALS_ORDERED',
          kde    = True)


# title and axis labels
plt.title(label   = "Logarithmic Distribution of TOTAL_MEALS_ORDERED")
plt.xlabel(xlabel = "TOTAL_MEALS_ORDERED") 
plt.ylabel(ylabel = "Count")

# displaying the histogram
plt.show()

##
sns.histplot(data   = chef,
          x      = 'log_TOTAL_PHOTOS_VIEWED',
          kde    = True)


# title and axis labels
plt.title(label   = "Logarithmic Distribution of TOTAL_PHOTOS_VIEWED")
plt.xlabel(xlabel = "TOTAL_PHOTOS_VIEWED") 
plt.ylabel(ylabel = "Count")

# displaying the histogram
plt.show()

##
sns.histplot(data   = chef,
          x      = 'CONTACTS_W_CUSTOMER_SERVICE',
          kde    = True)


# title and axis labels
plt.title(label   = "Logarithmic Distribution of CONTACTS_W_CUSTOMER_SERVICE ")
plt.xlabel(xlabel = "CONTACTS_W_CUSTOMER_SERVICE ") 
plt.ylabel(ylabel = "Count")

# displaying the histogram
plt.show()

sns.histplot(data   = chef,
          x      = 'UNIQUE_MEALS_PURCH',
          kde    = True)


# title and axis labels
plt.title(label   = "Logarithmic Distribution of UNIQUE_MEALS_PURCH")
plt.xlabel(xlabel = "UNIQUE_MEALS_PURCH")
plt.ylabel(ylabel = "Count")

# displaying the histogram
plt.show()

###
sns.histplot(data   = chef,
          x      = 'AVG_MEAN_RATING',
          kde    = True)


# title and axis labels
plt.title(label   = "Logarithmic Distribution of AVG_MEAN_RATING")
plt.xlabel(xlabel = "AVG_MEAN_RATING") 
plt.ylabel(ylabel = "Count")

# displaying the histogram
plt.show()

# %%
# Storing the list of columns to be used in correlation analysis
chef_log_data = ['log_REVENUE', 'log_AVG_TIME_PER_SITE_VISIT', 'log_TOTAL_MEALS_ORDERED',
                   'log_TOTAL_PHOTOS_VIEWED', 'log_CONTACTS_W_CUSTOMER_SERVICE', 'log_AVG_MEAN_RATING', 'log_UNIQUE_MEALS_PURCH']

chef_corr = chef[chef_log_data].corr(method = 'pearson')
chef_corr_revenue = chef_corr.loc[ : , 'log_REVENUE'].round(decimals = 2).sort_values(ascending = False)

# %%
import statsmodels.formula.api as smf

# %%
# building a base model with a log transformed response variable

lm_price_qual = smf.ols(formula = """log_REVENUE ~ log_AVG_TIME_PER_SITE_VISIT + log_TOTAL_MEALS_ORDERED + 
                        log_TOTAL_PHOTOS_VIEWED + log_CONTACTS_W_CUSTOMER_SERVICE  + log_AVG_MEAN_RATING + log_UNIQUE_MEALS_PURCH""",
                        data = chef)
results = lm_price_qual.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            log_REVENUE   R-squared:                       0.670
# Model:                            OLS   Adj. R-squared:                  0.669
# Method:                 Least Squares   F-statistic:                     657.3
# Date:                Sun, 12 Feb 2023   Prob (F-statistic):               0.00
# Time:                        19:19:21   Log-Likelihood:                -283.46
# No. Observations:                1946   AIC:                             580.9
# Df Residuals:                    1939   BIC:                             619.9
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...

# %%
# Creating a model type
lm_price_qual = smf.ols(formula = """log_REVENUE ~ log_AVG_TIME_PER_SITE_VISIT""",
                        data = chef)
results = lm_price_qual.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            log_REVENUE   R-squared:                       0.449
# Model:                            OLS   Adj. R-squared:                  0.448
# Method:                 Least Squares   F-statistic:                     1582.
# Date:                Sun, 12 Feb 2023   Prob (F-statistic):          1.32e-253
# Time:                        19:19:30   Log-Likelihood:                -784.13
# No. Observations:                1946   AIC:                             1572.
# Df Residuals:                    1944   BIC:                             1583.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       2.4650      0.128     19.314      0.000       2.215       2.715
# ...

# %%
# importing libraries
import pandas as pd # data science essentials
import matplotlib.pyplot as plt # data visualization
import seaborn as sns # enhanced data visualization
import statsmodels.formula.api as smf # regression modeling
from sklearn.model_selection import train_test_split # train/test split
import sklearn.linear_model # linear modeling in scikit-learn

# %%
# x-variables for normal y
x_var = ['NAME','EMAIL','FIRST_NAME','FAMILY_NAME','TOTAL_MEALS_ORDERED','UNIQUE_MEALS_PURCH','CONTACTS_W_CUSTOMER_SERVICE',
'PRODUCT_CATEGORIES_VIEWED','AVG_TIME_PER_SITE_VISIT','CANCELLATIONS_AFTER_NOON','PC_LOGINS','MOBILE_LOGINS','WEEKLY_PLAN','LATE_DELIVERIES ',               
'AVG_PREP_VID_TIME','LARGEST_ORDER_SIZE','AVG_MEAN_RATING','TOTAL_PHOTOS_VIEWED']

# x-variables for log y
x_var_log_y = ['log_AVG_TIME_PER_SITE_VISIT','log_TOTAL_MEALS_ORDERED',
                   'log_TOTAL_PHOTOS_VIEWED','log_CONTACTS_W_CUSTOMER_SERVICE',
               'log_AVG_MEAN_RATING','log_UNIQUE_MEALS_PURCH']

# %%
# preparing for scikit-learn

# preparing x-variables from the OLS model
x_data = chef.loc[ : ,x_var_log_y]



# preparing response variable
y_data = chef.loc[ : , 'log_REVENUE']


###############################################
## setting up more than one train-test split ##
###############################################
x_train, x_test, y_train, y_test = train_test_split(
            x_data, # x-variables (can change this)
            y_data, # y-variable  (can change this)
            test_size    = 0.25,
            random_state = 219)

# %%
# Setting a model name
model_name = "Linear Regression"

# Creating a model object
model = sklearn.linear_model.LinearRegression()

# training the  data for fittings
model_fit = model.fit(x_train, y_train)

# PREDICTING the new data
model_pred = model.predict(x_test)

# SCORING the results
model_train_score = model.score(x_train, y_train).round(4) # using R-square
model_test_score  = model.score(x_test, y_test).round(4)   # using R-square
model_gap         = abs(model_train_score - model_test_score).round(4)

# Displaying results
print('Training Score:', model_train_score)
print('Testing Score :', model_test_score)
print('Train-Test Gap:', model_gap)
# Out:
# Training Score: 0.6681
# Testing Score : 0.673
# Train-Test Gap: 0.0049

# %%
# zipping each of the feature name to the coefficient
model_coefficients = zip(x_train.columns,
                         model.coef_.round(decimals = 2))

coefficient_lst = [('intercept', model.intercept_.round(decimals = 2))]

for coefficient in model_coefficients:
    coefficient_lst.append(coefficient)
    
for pair in coefficient_lst:
    print(pair)
# Out:
# ('intercept', 4.07)
# ('log_AVG_TIME_PER_SITE_VISIT', 0.48)
# ('log_TOTAL_MEALS_ORDERED', 0.29)
# ('log_TOTAL_PHOTOS_VIEWED', 0.03)
# ('log_CONTACTS_W_CUSTOMER_SERVICE', 0.08)
# ('log_AVG_MEAN_RATING', -0.46)
# ('log_UNIQUE_MEALS_PURCH', 0.13)

# %%
# dynamically printing results
ols_model =  f"""\
Model Name:     {model_name}
Train_Score:    {model_train_score}
Test_Score:     {model_test_score}
Train-Test Gap: {model_gap}

Coefficents
-----------
{pd.DataFrame(data = coefficient_lst, columns = ["Feature", "Coefficient"])}"""

print(ols_model)
# Out:
# Model Name:     Linear Regression
# Train_Score:    0.6681
# Test_Score:     0.673
# Train-Test Gap: 0.0049
#
# Coefficents
# -----------
#                            Feature  Coefficient
# 0                        intercept         4.07
# 1      log_AVG_TIME_PER_SITE_VISIT         0.48
# 2          log_TOTAL_MEALS_ORDERED         0.29
# 3          log_TOTAL_PHOTOS_VIEWED         0.03
# 4  log_CONTACTS_W_CUSTOMER_SERVICE         0.08
# 5              log_AVG_MEAN_RATING        -0.46
# 6           log_UNIQUE_MEALS_PURCH         0.13

# %%
# Setting, fitting and predicting a model name
model_name = "ARD Regression"
model = sklearn.linear_model.ARDRegression()
model_fit = model.fit(x_train, y_train)
model_pred = model.predict(x_test)


# SCORING the results
model_train_score = model.score(x_train, y_train).round(4) # using R-square
model_test_score  = model.score(x_test, y_test).round(4)   # using R-square
model_gap         = abs(model_train_score - model_test_score).round(4)


# displaying results
print('Training Score :', model_train_score)
print('Testing Score  :', model_test_score)
print('Train-Test Gap :', model_gap)
# Out:
# Training Score : 0.6681
# Testing Score  : 0.6726
# Train-Test Gap : 0.0045

# %%
# dynamically printing results
ard_model =  f"""\
Model Name:     {model_name}
Train_Score:    {model_train_score}
Test_Score:     {model_test_score}
Train-Test Gap: {model_gap}

Coefficents
-----------
{pd.DataFrame(data = coefficient_lst, columns = ["Feature", "Coefficient"])}"""

print(ard_model)
# Out:
# Model Name:     ARD Regression
# Train_Score:    0.6681
# Test_Score:     0.6726
# Train-Test Gap: 0.0045
#
# Coefficents
# -----------
#                            Feature  Coefficient
# 0                        intercept         4.07
# 1      log_AVG_TIME_PER_SITE_VISIT         0.48
# 2          log_TOTAL_MEALS_ORDERED         0.29
# 3          log_TOTAL_PHOTOS_VIEWED         0.03
# 4  log_CONTACTS_W_CUSTOMER_SERVICE         0.08
# 5              log_AVG_MEAN_RATING        -0.46
# 6           log_UNIQUE_MEALS_PURCH         0.13

# %%
##importing libraries            
import matplotlib.pyplot as plt               
from sklearn.tree     import DecisionTreeRegressor    
from sklearn.ensemble import RandomForestRegressor     
from sklearn.ensemble import GradientBoostingRegressor 
from sklearn.model_selection import train_test_split 
from sklearn.tree import plot_tree                  
from sklearn.model_selection import RandomizedSearchCV

# %%
# declared  hyperparameter space
criterion_range = ["squared_error", "friedman_mse", "absolute_error"]
splitter_range  = ["best", "random"]
depth_range     = range(1, 10, 1) 
leaf_range      = range(1, 205,25 )


# creating the hyperparameter grid
param_grid = {'criterion' : criterion_range,
              'splitter' : splitter_range,
              'max_depth': depth_range,
              'min_samples_leaf' : leaf_range}

tuned_tree = DecisionTreeRegressor(random_state = 219)


tuned_tree_cv = RandomizedSearchCV(estimator             = tuned_tree,
                                   param_distributions   = param_grid,
                                   cv                    = 5,
                                   n_iter                = 1000,
                                   random_state          = 219)


# FITTING to the FULL DATASET and printing the optimal parameters and best score
tuned_tree_cv.fit(x_data, y_data)
print("Tuned Parameters  :", tuned_tree_cv.best_params_)
print("Tuned Training AUC:", tuned_tree_cv.best_score_.round(4))
# Out:
# /Users/ebunoluwaadejumo/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:292: UserWarning: The total space of parameters 486 is smaller than n_iter=1000. Running 486 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Tuned Parameters  : {'splitter': 'best', 'min_samples_leaf': 26, 'max_depth': 8, 'criterion': 'squared_error'}
# Tuned Training AUC: 0.6558

# %%
model= DecisionTreeRegressor(splitter ='best',
                            min_samples_leaf = 27,
                            max_depth = 8,
                            criterion = 'mse',
                            random_state = 219)
model.fit(x_train, y_train)


# PREDICTING, scoring and printing based on the testing set
model.predict(x_test)
print(model.score(x_train, y_train))
print(model.score(x_test, y_test))


train_score =(model.score(x_train, y_train))
test_score =(model.score(x_test, y_test))
print(abs(train_score - test_score))
# Out:
# 0.7584271886480735
# 0.7123997113547094
# 0.046027477293364094
# /Users/ebunoluwaadejumo/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(

# %%
print(f""" From the model, The model {DecisionTreeRegressor} was adopted, and the following were generated:\n
        Test score: {test_score.round(2)}
        Training Score:{train_score.round(2)}
        Train-Test Gap: {abs(train_score - test_score).round(2)}
        """)
# Out:
#  From the model, The model <class 'sklearn.tree._classes.DecisionTreeRegressor'> was adopted, and the following were generated:
#
#         Test score: 0.71
#         Training Score:0.76
#         Train-Test Gap: 0.05
